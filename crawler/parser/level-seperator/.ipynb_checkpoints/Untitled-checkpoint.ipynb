# %%
import json
import math
from tqdm import tqdm

# %%
categories = ['next','reactRouter','reactHookForm','styledComponents','reactQuery','tailwind','reactRedux','axios','recoil']

# %%
category = 'recoil'
f = open('../../data/complete-dictionarys/1/mean-word-frequency/{}.json'.format(category),'r')
datas = json.load(f)
for idx,data in enumerate(datas):
    word = data['word']
    if word in keys:
        tmp ={**data, 'mean': allDic[word]}
        datas[idx] = tmp
f = open('../../data/complete-dictionarys/1/mean-word-frequency-level/{}.json'.format(category),'w')
json.dump(datas, f, ensure_ascii=False, indent=4)

# %%
f = open('../../data/complete-dictionarys/1/mean-word-frequency-level/recoil.json','rb')
recoil = json.load(f)

# %%
recoil
# Out:
# [{'word': 'state', 'mean': "['상태', '국가의', '말하다']", 'frequency': '104'},
#  {'word': 'selector',
#   'mean': "['(스포츠 팀의) 선발 위원', '(엔진·기계 등에서 기능) 선택 장치']",
#   'frequency': '63'},
#  {'word': 'value', 'mean': "['가치', '소중하게 생각하다', '평가하다']", 'frequency': '55'},
#  {'word': 'recoil', 'mean': ['움찔하다', '반동', '움츠러들다'], 'frequency': '51'},
#  {'word': 'react', 'mean': "['반응하다', '화학 반응을 일으키다']", 'frequency': '47'},
#  {'word': 'use', 'mean': "['쓰다', '사용', '용도']", 'frequency': '42'},
#  {'word': 'component', 'mean': "['요소', '부품']", 'frequency': '28'},
#  {'word': 'example',
#   'mean': "['(설명·증명을 위한) 예', '(대표적인) 본보기, 전형', '(따라 배울 만한) 본보기']",
#   'frequency': '27'},
#  {'word': 'function', 'mean': "['기능', '기능하다', '행사']", 'frequency': '24'},
#  {'word': 'used', 'mean': "['중고의']", 'frequency': '23'},
#  {'word': 'set', 'mean': "['놓다', '세트', '위치한']", 'frequency': '23'},
#  {'word': 'query', 'mean': "['문의', '문의하다', '묻다']", 'frequency': '21'},
# ...

# %%
allDic = {}
for d in react:
    allDic[d['word']]=d['mean']

# %%
keys = list(allDic.keys())

# %%
datas
# Out:
# [{'word': 'state', 'mean': "['상태', '국가의', '말하다']", 'frequency': '104'},
#  {'word': 'selector',
#   'mean': "['(스포츠 팀의) 선발 위원', '(엔진·기계 등에서 기능) 선택 장치']",
#   'frequency': '63'},
#  {'word': 'value', 'mean': "['가치', '소중하게 생각하다', '평가하다']", 'frequency': '55'},
#  {'word': 'recoil', 'mean': ['움찔하다', '반동', '움츠러들다'], 'frequency': '51'},
#  {'word': 'react', 'mean': "['반응하다', '화학 반응을 일으키다']", 'frequency': '47'},
#  {'word': 'use', 'mean': "['쓰다', '사용', '용도']", 'frequency': '42'},
#  {'word': 'component', 'mean': "['요소', '부품']", 'frequency': '28'},
#  {'word': 'example',
#   'mean': "['(설명·증명을 위한) 예', '(대표적인) 본보기, 전형', '(따라 배울 만한) 본보기']",
#   'frequency': '27'},
#  {'word': 'function', 'mean': "['기능', '기능하다', '행사']", 'frequency': '24'},
#  {'word': 'used', 'mean': "['중고의']", 'frequency': '23'},
#  {'word': 'set', 'mean': "['놓다', '세트', '위치한']", 'frequency': '23'},
#  {'word': 'query', 'mean': "['문의', '문의하다', '묻다']", 'frequency': '21'},
# ...

# %%
f = open('../../data/complete-dictionarys/1/mean-word-frequency-level/reactRedux.json'.format(category),'r')
datas = json.load(f)

# %%
datas
# Out:
# [{'word': 'react',
#   'mean': "['반응하다', '화학 반응을 일으키다']",
#   'frequency': '166',
#   'level': 1,
#   'category': 'reactRedux'},
#  {'word': 'store',
#   'mean': "['백화점', '저장하다', '가게']",
#   'frequency': '147',
#   'level': 1,
#   'category': 'reactRedux'},
#  {'word': 'component',
#   'mean': "['요소', '부품']",
#   'frequency': '140',
#   'level': 1,
#   'category': 'reactRedux'},
#  {'word': 'function',
#   'mean': "['기능', '기능하다', '행사']",
#   'frequency': '98',
#   'level': 1,
#   'category': 'reactRedux'},
#  {'word': 'state',
#   'mean': "['상태', '국가의', '말하다']",
#   'frequency': '75',
#   'level': 1,
#   'category': 'reactRedux'},
#  {'word': 'dispatch',
#   'mean': "['보내다', '파견; 발송', '긴급 공문']",
#   'frequency': '73',
#   'level': 1,
#   'category': 'reactRedux'},
#  {'word': 'connect',
#   'mean': "['잇다', '연결하다', '접속하다']",
#   'frequency': '72',
#   'level': 1,
#   'category': 'reactRedux'},
#  {'word': 'use',
#   'mean': "['쓰다', '사용', '용도']",
#   'frequency': '68',
#   'level': 1,
# ...
